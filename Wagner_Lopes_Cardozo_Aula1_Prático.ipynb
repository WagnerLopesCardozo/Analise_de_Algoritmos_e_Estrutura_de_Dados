# %% [markdown]
# <a href="https://colab.research.google.com/github/WagnerLopesCardozo/Analise_de_Algoritmos_e_Estrutura_de_Dados/blob/main/Wagner_Lopes_Cardozo_Aula1_Pr%C3%A1tico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Capa_Exercício_Aula_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #<font color=lightgreen>Estudo 1 - Recursivo
#
# ##Algoritimo com a função recursiva implementada, porém este algoritmo por ser recursivo tem uma profundidade de busca de 966 vezes dentro da função recursiva no vetor de 100.000 números, sendo uma limitação do Python. Além do tempo de execução ser muito alto devido ao seu custo assintótico Big(O) ser de O(n²) representando uma complexidade quadrática.
#
# ##Solução:
#
# ## Implementar o mesmo algoritimo de forma interativa.

# %%
print(98*'*')
print('Algoritmo que calcula o maior número primo em um arrey de 100.000 mil números usando recursividade')
print(98*'*')

import random
import time
import math

# Função recursiva para verificar se um número é primo
def is_prime(n, divisor=None):
    if n < 2:
        return False
    if divisor is None:
        divisor = n - 1
    if divisor == 1:
        return True
    if n % divisor == 0:
        return False
    return is_prime(n, divisor - 1)   #Não esquecer de fazer comentário mais detalhados para a função de recursividade

# Função para encontrar o maior número primo em um vetor
def find_largest_prime(arr):
    max_prime = None
    for num in arr:
        if is_prime(num):
            if max_prime is None or num > max_prime:
                max_prime = num
    return max_prime

# Gerando um vetor aleatório de 100.000 elementos       #ATENÇÃO
arr = [random.randint(1, 966) for _ in range(100000)]   #966 e se for maior que este número para a profundidade vai dar erro na execução do algoritmo

# Medindo o tempo de execução
start_time = time.time()
largest_prime = find_largest_prime(arr)
end_time = time.time()

# Calculando o tempo de execução
execution_time = end_time - start_time

# Análise de Complexidade
# A função is_prime tem complexidade O(n) no pior caso, onde n é o número sendo testado.
# A função find_largest_prime tem complexidade O(m * n), onde m é o número de elementos no vetor e n é o valor médio dos números no vetor.

complexity_analysis = """
Análise de Complexidade:
- A função is_prime tem complexidade O(n), onde n é o número sendo testado.
- A função find_largest_prime, que verifica cada número no vetor, tem complexidade O(m * n),
  onde m é o tamanho do vetor e n é o valor médio dos números no vetor.

Portanto, a complexidade total é O(m * n), que é aproximadamente O(n^2) para grandes n,
considerando que m = n (números no vetor e número sendo testado).
Esta é uma complexidade quadrática.
"""

# Exibindo os resultados
print(f"O maior número primo encontrado foi: {largest_prime}")
print(f"Tempo de execução: {execution_time:.6f} segundos")
print(complexity_analysis)
# Out:
# **************************************************************************************************
# Algoritmo que calcula o maior número primo em um arrey de 100.000 mil números usando recursividade
# **************************************************************************************************
# O maior número primo encontrado foi: 953
# Tempo de execução: 10.495347 segundos
#
# Análise de Complexidade:
# - A função is_prime tem complexidade O(n), onde n é o número sendo testado.
# - A função find_largest_prime, que verifica cada número no vetor, tem complexidade O(m * n),
#   onde m é o tamanho do vetor e n é o valor médio dos números no vetor.
#
# Portanto, a complexidade total é O(m * n), que é aproximadamente O(n^2) para grandes n,
# considerando que m = n (números no vetor e número sendo testado).
# Esta é uma complexidade quadrática.

# %% [markdown]
# #<font color=lightgreen>Estudo 2 - Interativo
#
# ##O mesmo algoritimo com a função interativa implementada, agora este algoritmo pode ser executado com uma profundidade de 1.000.000 pecorrendo todo o vetor de 100.000 números.Além do tempo de execução ser bem mais baixo devido ao seu custo assintótico Big(O) ser de O(m*sqrt(n)) representando uma complexidade denominada sublinear.
#
# #Definição
#
# Um algoritmo de complexidade sublinear é aquele cuja complexidade de tempo cresce mais lentamente do que o tamanho da entrada. Isso significa que, à medida que o tamanho da entrada aumenta, o tempo que o algoritmo leva para ser executado aumenta a uma taxa mais lenta.
#
# Exemplos de complexidades sublineares incluem:
#
# * O(log n): Busca binária em uma lista ordenada.
#
# * O(sqrt(n)): Algoritmos que iteram sobre a raiz quadrada do tamanho da entrada.
#
# Esses algoritmos são geralmente muito eficientes, pois podem lidar com grandes entradas em um tempo relativamente curto. Eles são frequentemente usados em tarefas como pesquisa, classificação e processamento de grandes conjuntos de dados.
#
# Fontes:
#
# * https://stackoverflow.com/questions/32311924/what-are-sublinear-algorithms

# %%
print(98*'*')
print('Algoritmo que calcula o maior número primo em um arrey de 100.000 mil números usando iteratividade')
print(98*'*')


import random
import time
import math

# Função iterativa para verificar se um número é primo
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True                 #Não esquecer de fazer comentários mais detalhados para a função de iteratividade

# Função para encontrar o maior número primo em um vetor
def find_largest_prime(arr):
    max_prime = None
    for num in arr:
        if is_prime(num):
            if max_prime is None or num > max_prime:
                max_prime = num
    return max_prime

# Gerando um vetor aleatório de 100.000 elementos
arr = [random.randint(1, 1000000) for _ in range(100000)]

# Medindo o tempo de execução
start_time = time.time()
largest_prime = find_largest_prime(arr)
end_time = time.time()

# Calculando o tempo de execução
execution_time = end_time - start_time

# Análise de Complexidade
# A função is_prime tem complexidade O(√n) no pior caso, onde n é o número sendo testado.
# A função find_largest_prime tem complexidade O(m * √n), onde m é o número de elementos no vetor e n é o valor médio dos números no vetor.

complexity_analysis = """
Análise de Complexidade:
- A função is_prime tem complexidade O(√n), onde n é o número sendo testado.
- A função find_largest_prime, que verifica cada número no vetor, tem complexidade O(m * √n),
  onde m é o tamanho do vetor e n é o valor médio dos números no vetor.

Portanto, a complexidade total é O(m * √n), que é mais eficiente do que O(n^2) para grandes n.
Esta é uma complexidade sublinear.
"""

# Exibindo os resultados
print(f"O maior número primo encontrado foi: {largest_prime}")
print(f"Tempo de execução: {execution_time:.6f} segundos")
print(complexity_analysis)
# Out:
# **************************************************************************************************
# Algoritmo que calcula o maior número primo em um arrey de 100.000 mil números usando iteratividade
# **************************************************************************************************
# O maior número primo encontrado foi: 999961
# Tempo de execução: 0.530053 segundos
#
# Análise de Complexidade:
# - A função is_prime tem complexidade O(√n), onde n é o número sendo testado.
# - A função find_largest_prime, que verifica cada número no vetor, tem complexidade O(m * √n),
#   onde m é o tamanho do vetor e n é o valor médio dos números no vetor.
#
# Portanto, a complexidade total é O(m * √n), que é mais eficiente do que O(n^2) para grandes n.
# Esta é uma complexidade sublinear.

# %% [markdown]
# #<font color=lightgreen>Estudo 3 - Representação Gráfica Para Visualização da Análise Assintótica
#
# ##Este algoritmo é o mesmo acima já implementado porém com a implementação das representações gráficas para comparar o custo temporal da iteratividade com a recursividade e a curva da análise assintótica Big(O)

# %%
print(169*'*')
print('Algoritmo que calcula o maior número primo em um arrey de 100.000 mil números usando iteratividade e recursividade e exibe representações gráficas da análise assintótica')
print(169*'*')

import random
import time
import math
import matplotlib.pyplot as plt        #Vamos detalhar por meio de comentários as linhas das funções de iteratividade, recursividade e função para encontrar o maior número primo

# Função iterativa para verificar se um número é primo
def is_prime_iterative(n):

    if n <= 1:   # Verifica se n é menor ou igual a 1, pois números menores ou iguais a 1 não são primos
        return False

    if n <= 3:   # Verifica se n é 2 ou 3, pois esses números são primos
        return True

    if n % 2 == 0 or n % 3 == 0:    # Elimina múltiplos de 2 e 3 que não são primos (exceto o próprio 2 e 3)
        return False

    i = 5     # Inicia o divisor i em 5 e incrementa 6 a cada passo para eliminar múltiplos de 2 e 3
    while i * i <= n:

        if n % i == 0 or n % (i + 2) == 0:     # Se n for divisível por i ou i + 2, não é primo
            return False
        i += 6

    return True     # Se passar por todas as verificações, n é primo

# Função recursiva para verificar se um número é primo
def is_prime_recursive(n, divisor=None):

    if n < 2:      # Números menores que 2 não são primos
        return False

    if divisor is None:     # Se o divisor não for especificado, inicializa com n - 1
        divisor = n - 1

    if divisor == 1:     # Se o divisor for 1, n é primo
        return True

    if n % divisor == 0:     # Se n for divisível por divisor, não é primo
        return False

    return is_prime_recursive(n, divisor - 1)     # Chama a função recursivamente, reduzindo o divisor

# Função para encontrar o maior número primo em um vetor
def find_largest_prime(arr, prime_func):

    max_prime = None  # Inicializa a variável para armazenar o maior número primo

    for num in arr:     # Itera sobre cada número no vetor

        if prime_func(num):    # Verifica se o número é primo usando a função fornecida (iterativa ou recursiva)

            if max_prime is None or num > max_prime:     # Se max_prime for None ou o número atual for maior que max_prime, atualiza max_prime
                max_prime = num

    return max_prime     # Retorna o maior número primo encontrado

# Gerando um vetor aleatório de 100.000 elementos, com valores entre 1 e 100
arr = [random.randint(1, 960) for _ in range(100000)]

# Medindo o tempo de execução para o método iterativo
start_time_iterative = time.time()  # Inicia a contagem do tempo
largest_prime_iterative = find_largest_prime(arr, is_prime_iterative)  # Encontra o maior primo usando a função iterativa
end_time_iterative = time.time()  # Finaliza a contagem do tempo
execution_time_iterative = end_time_iterative - start_time_iterative  # Calcula o tempo de execução

# Medindo o tempo de execução para o método recursivo
start_time_recursive = time.time()  # Inicia a contagem do tempo
largest_prime_recursive = find_largest_prime(arr, is_prime_recursive)  # Encontra o maior primo usando a função recursiva
end_time_recursive = time.time()  # Finaliza a contagem do tempo
execution_time_recursive = end_time_recursive - start_time_recursive  # Calcula o tempo de execução

# Exibindo os resultados
print(f"Maior número primo encontrado (Iterativo): {largest_prime_iterative}")
print(f"Tempo de execução (Iterativo): {execution_time_iterative:.6f} segundos")
print(f"Maior número primo encontrado (Recursivo): {largest_prime_recursive}")
print(f"Tempo de execução (Recursivo): {execution_time_recursive:.6f} segundos")

# Plotando os gráficos de comparação de tempo de execução e da análise assintótica Big(O)
plt.figure(figsize=(14, 6))

# Gráfico de tempo de execução
plt.subplot(1, 2, 1)
plt.bar(['Iterativo', 'Recursivo'], [execution_time_iterative, execution_time_recursive], color=['blue', 'red'])
plt.ylabel('Tempo de Execução (s)')
plt.title('Comparação de Tempo de Execução: Método Iterativo vs Recursivo')

# Gráfico da análise assintótica Big(O)
n_values = list(range(1, 101))
iterative_big_o = [math.sqrt(n) for n in n_values]  # Estimativa O(√n) para o iterativo
recursive_big_o = n_values  # O(n) para o recursivo

plt.subplot(1, 2, 2)
plt.plot(n_values, iterative_big_o, label="Iterativo O(√n)", color='blue', marker='o')
plt.plot(n_values, recursive_big_o, label="Recursivo O(n)", color='red', marker='o')
plt.xlabel('Valor de n')
plt.ylabel('Função Assintótica')
plt.title('Análise Assintótica (Big-O)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# *************************************************************************************************************************************************************************
# Algoritmo que calcula o maior número primo em um arrey de 100.000 mil números usando iteratividade e recursividade e exibe representações gráficas da análise assintótica
# *************************************************************************************************************************************************************************
# Maior número primo encontrado (Iterativo): 953
# Tempo de execução (Iterativo): 0.036113 segundos
# Maior número primo encontrado (Recursivo): 953
# Tempo de execução (Recursivo): 8.982873 segundos

# %% [markdown]
# #<font color=lightgreen>Referência Bibliográfica
#
# * https://docs.python.org/pt-br/3.7/library/random.html
#
# * https://docs.python.org/pt-br/3.9/library/time.html
#
# * https://docs.python.org/pt-br/3/library/math.html
#
# * https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
#
# * https://saturncloud.io/blog/whats-the-hardware-spec-for-google-colaboratory/

# %% [markdown]
# #<font color=lightgreen>Anexos

# %% [markdown]
# ##Linhas de código para sumarizar os detalhes técnicos do ambiente de desenvolvimento integrado IDE do processamento em nuvem do Google Colab

# %%
# !cat /proc/cpuinfo # Para informações sobre o processador
# !cat /proc/meminfo # Para informações sobre a memória RAM
# !df -h # Para informações sobre o armazenamento
# !python --version # Para a versão do Python
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# MemTotal:       13290452 kB
# MemFree:         6064268 kB
# MemAvailable:   11423844 kB
# Buffers:          397452 kB
# Cached:          5102072 kB
# SwapCached:            0 kB
# Active:           765424 kB
# Inactive:        5994840 kB
# Active(anon):       1312 kB
# Inactive(anon):  1261188 kB
# Active(file):     764112 kB
# Inactive(file):  4733652 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               196 kB
# Writeback:             0 kB
# AnonPages:       1260804 kB
# Mapped:           783028 kB
# Shmem:              1704 kB
# KReclaimable:     187380 kB
# Slab:             238140 kB
# SReclaimable:     187380 kB
# SUnreclaim:        50760 kB
# KernelStack:        6064 kB
# PageTables:        18972 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645224 kB
# Committed_AS:    3591712 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       80524 kB
# VmallocChunk:          0 kB
# Percpu:             1136 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      152376 kB
# DirectMap2M:     5087232 kB
# DirectMap1G:    10485760 kB
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          79G   31G   48G  40% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G   92K  6.4G   1% /var/colab
# /dev/sda1       106G   87G   19G  82% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# Python 3.10.12

# %% [markdown]
# ##Linha de código para detalhes tecnicos da GPU do ambiente de desenvolvimento integrado IDE do Google Colab

# %%
# !nvidia-smi
# Out:
# Sat Aug 10 03:15:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
